# %%
import pandas as pd

# %%
df.head()
# Out:
#    ID  Category      Question                                        Answer
# 0   1  Greeting            hi  Hello! Welcome to the College Query Chatbot.
# 1   2  Greeting         hello                 Hi! How can I help you today?
# 2   3  Greeting  good morning         Good Morning! Welcome to our college.
# 3   4  Greeting  good evening           Good Evening! How can I assist you?
# 4   5  Greeting           bye                   Thank you! Have a nice day.

# %%
df.tail()
# Out:
#    ID   Category    Question  \
# 5   6  Admission   admission
# 6   7    Courses     courses
# 7   8    Library     library
# 8   9     Hostel      hostel
# 9  10  Placement  placements
#
#                                               Answer
# 5  Please visit the Admission Office for admissio...
# 6  We offer CSE IT ECE EEE AIML Civil and Mechani...
# 7             The library is open from 9 AM to 5 PM.
# 8  Hostel facilities are available for both boys ...
# 9  Our Placement Cell conducts training and campu...

# %%
df.shape
# Out:
# (10, 4)

# %%
df.columns
# Out:
# Index(['ID', 'Category', 'Question', 'Answer'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        10 non-null     int64
#  1   Category  10 non-null     object
#  2   Question  10 non-null     object
#  3   Answer    10 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
df.describe(include="all")
# Out:
#               ID  Category Question  \
# count   10.00000        10       10
# unique       NaN         6       10
# top          NaN  Greeting       hi
# freq         NaN         5        1
# mean     5.50000       NaN      NaN
# std      3.02765       NaN      NaN
# min      1.00000       NaN      NaN
# 25%      3.25000       NaN      NaN
# 50%      5.50000       NaN      NaN
# 75%      7.75000       NaN      NaN
# max     10.00000       NaN      NaN
#
#                                               Answer
# count                                             10
# unique                                            10
# top     Hello! Welcome to the College Query Chatbot.
# freq                                               1
# mean                                             NaN
# std                                              NaN
# min                                              NaN
# 25%                                              NaN
# ...

# %%
df.isnull().sum()
# Out:
# ID          0
# Category    0
# Question    0
# Answer      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Category"].unique()
# Out:
# array(['Greeting', 'Admission', 'Courses', 'Library', 'Hostel',
#        'Placement'], dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Category
# Greeting     5
# Admission    1
# Courses      1
# Library      1
# Hostel       1
# Placement    1
# Name: count, dtype: int64

# %%
df["Question"] = df["Question"].str.lower()

# %%
df.to_csv("../cleaned_dataset/cleaned_college_faq.csv", index=False)

# %%
cleaned_df = pd.read_csv("../cleaned_dataset/cleaned_college_faq.csv")
cleaned_df.head()
# Out:
#    ID  Category      Question                                        Answer
# 0   1  Greeting            hi  Hello! Welcome to the College Query Chatbot.
# 1   2  Greeting         hello                 Hi! How can I help you today?
# 2   3  Greeting  good morning         Good Morning! Welcome to our college.
# 3   4  Greeting  good evening           Good Evening! How can I assist you?
# 4   5  Greeting           bye                   Thank you! Have a nice day.

# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/college_faq.csv", sep=";")

# %%
df.head()
# Out:
#                          ID,Category,Question,Answer
# 0  1,Greeting,hi,Hello! Welcome to the College Qu...
# 1     2,Greeting,hello,Hi! How can I help you today?
# 2  3,Greeting,good morning,Good Morning! Welcome ...
# 3  4,Greeting,good evening,Good Evening! How can ...
# 4         5,Greeting,bye,Thank you! Have a nice day.

# %%
import pandas as pd

df = pd.read_csv(
    "../dataset/college_faq.csv",
    on_bad_lines="skip"
)

print(df.shape)
# Out:
# (101, 4)

# %%
import pandas as pd

df = pd.read_csv("../dataset/college_faq.csv", on_bad_lines="skip")

print(df.shape)
print(df.head())
# Out:
# (101, 4)
#    ID  Category      Question                                        Answer
# 0   1  Greeting            hi  Hello! Welcome to the College Query Chatbot.
# 1   2  Greeting         hello                 Hi! How can I help you today?
# 2   3  Greeting  good morning         Good Morning! Welcome to our college.
# 3   4  Greeting  good evening           Good Evening! How can I assist you?
# 4   5  Greeting           bye                   Thank you! Have a nice day.

# %%
print(df.isnull().sum())
# Out:
# ID          0
# Category    0
# Question    0
# Answer      0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        101 non-null    int64
#  1   Category  101 non-null    object
#  2   Question  101 non-null    object
#  3   Answer    101 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
print(df["Category"].value_counts())
# Out:
# Category
# Library        13
# Admission      11
# Greeting       10
# Placement      10
# Faculty        10
# Fees           10
# Examination    10
# Courses         9
# Hostel          9
# Campus          9
# Name: count, dtype: int64

# %%
df.to_csv("../cleaned_dataset/cleaned_college_faq.csv", index=False)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
df.head(10)
# Out:
#    ID  Category      Question                                        Answer
# 0   1  Greeting            hi  Hello! Welcome to the College Query Chatbot.
# 1   2  Greeting         hello                 Hi! How can I help you today?
# 2   3  Greeting  good morning         Good Morning! Welcome to our college.
# 3   4  Greeting  good evening           Good Evening! How can I assist you?
# 4   5  Greeting           bye                   Thank you! Have a nice day.
# 5   6  Greeting   how are you         I am doing great! How can I help you?
# 6   7  Greeting   who are you               I am the College Query Chatbot.
# 7   8  Greeting     thank you                You're welcome! Happy to help.
# 8   9  Greeting        thanks                               You're welcome.
# 9  10  Greeting    good night                        Good Night! Take care.

# %%
df.tail(10)
# Out:
#       ID   Category                 Question  \
# 91    96     Campus         medical facility
# 92    97     Campus            student clubs
# 93    98     Campus                      NSS
# 94    99     Campus                      NCC
# 95   100     Campus          college timings
# 96   101    Library         where is library
# 97   102    Library         library location
# 98   103    Library     how to reach library
# 99   104  Admission  how can i get admission
# 100  105  Admission      how to join college
#
#                                                 Answer
# 91     First aid and medical assistance are available.
# 92    Various technical and cultural clubs are active.
# 93             NSS activities are conducted regularly.
# 94        NCC unit is available for eligible students.
# 95   College working hours are from 9:00 AM to 4:30...
# 96                  The library is located in Block A.
# 97                  The library is located in Block A.
# ...

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (101, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        101 non-null    int64
#  1   Category  101 non-null    object
#  2   Question  101 non-null    object
#  3   Answer    101 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
print(df.columns)
# Out:
# Index(['ID', 'Category', 'Question', 'Answer'], dtype='object')

# %%
print(df.dtypes)
# Out:
# ID           int64
# Category    object
# Question    object
# Answer      object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# ID          0
# Category    0
# Question    0
# Answer      0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()

# %%
print(df["Category"].unique())
# Out:
# ['Greeting' 'Admission' 'Courses' 'Library' 'Hostel' 'Placement' 'Fees'
#  'Faculty' 'Examination' 'Campus']

# %%
print(df["Category"].value_counts())
# Out:
# Category
# Library        13
# Admission      11
# Greeting       10
# Placement      10
# Faculty        10
# Fees           10
# Examination    10
# Courses         9
# Hostel          9
# Campus          9
# Name: count, dtype: int64

# %%
print(df["Question"].nunique())
# Out:
# 100

# %%
print(df["Answer"].nunique())
# Out:
# 98

# %%
print(df[df["Question"]==""])
# Out:
# Empty DataFrame
# Columns: [ID, Category, Question, Answer]
# Index: []

# %%
print(df[df["Answer"]==""])
# Out:
# Empty DataFrame
# Columns: [ID, Category, Question, Answer]
# Index: []

# %%
df["Question"] = df["Question"].str.lower()

# %%
df["Question"] = df["Question"].str.strip()
df["Answer"] = df["Answer"].str.strip()

# %%
df["Answer_Length"] = df["Answer"].apply(len)
df[["Answer","Answer_Length"]].head()
# Out:
#                                          Answer  Answer_Length
# 0  Hello! Welcome to the College Query Chatbot.             44
# 1                 Hi! How can I help you today?             29
# 2         Good Morning! Welcome to our college.             37
# 3           Good Evening! How can I assist you?             35
# 4                   Thank you! Have a nice day.             27

# %%
df.sample(5)
# Out:
#      ID     Category         Question  \
# 83   87  Examination      hall ticket
# 95  100       Campus  college timings
# 55   59    Placement  resume building
# 62   66         Fees         late fee
# 57   61         Fees    fee structure
#
#                                                Answer  Answer_Length
# 83    Hall tickets can be downloaded from the portal.             47
# 95  College working hours are from 9:00 AM to 4:30...             50
# 55         Resume preparation sessions are organized.             42
# 62     Late fee may be applicable after the due date.             46
# 57  Please contact the Accounts Office for fee det...             51

# %%
df.to_csv("../cleaned_dataset/cleaned_college_faq.csv", index=False)

# %%
clean_df = pd.read_csv("../cleaned_dataset/cleaned_college_faq.csv")
clean_df.head()
# Out:
#    ID  Category      Question                                        Answer  \
# 0   1  Greeting            hi  Hello! Welcome to the College Query Chatbot.
# 1   2  Greeting         hello                 Hi! How can I help you today?
# 2   3  Greeting  good morning         Good Morning! Welcome to our college.
# 3   4  Greeting  good evening           Good Evening! How can I assist you?
# 4   5  Greeting           bye                   Thank you! Have a nice day.
#
#    Answer_Length
# 0             44
# 1             29
# 2             37
# 3             35
# 4             27

# %%
print(clean_df.shape)
# Out:
# (101, 5)
