# %%
import sys
sys.path.append("../src")

from conversation_state import ConversationState

# %%
state = ConversationState()

print("Last Intent:", state.get_last_intent())
print("Last Question:", state.get_last_question())
# Out:
# Last Intent: None
# Last Question: None

# %%
state.update(
    "courses",
    "What courses are available?"
)

print("Last Intent:", state.get_last_intent())
print("Last Question:", state.get_last_question())
# Out:
# Last Intent: courses
# Last Question: What courses are available?

# %%
state.update(
    "fees",
    "What is the fee?"
)

print("Last Intent:", state.get_last_intent())
print("Last Question:", state.get_last_question())
# Out:
# Last Intent: fees
# Last Question: What is the fee?

# %%
print(state.get_history())
# Out:
# [{'question': 'What courses are available?', 'intent': 'courses'}, {'question': 'What is the fee?', 'intent': 'fees'}, {'question': 'What is the fee?', 'intent': 'fees'}]

# %%
state.reset()

print("Last Intent:", state.get_last_intent())
print("Last Question:", state.get_last_question())
print("History:", state.get_history())
# Out:
# Last Intent: None
# Last Question: None
# History: []
